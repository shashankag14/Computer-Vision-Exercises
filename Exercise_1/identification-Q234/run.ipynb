# %%
# %run 'identification.py'
# Out:
# PART 2A:
# PART 2B:
# PART 2C :
# distance functions:
# ['l2', 'intersect', 'chi2']
#
#
# histogram types:
# ['grayvalue', 'rgb', 'rg', 'dxdy']
#
#
# compare image "./model/obj1__0.png" to "./model/obj91__0.png":
# [[0.05760147 0.0578308  0.11649707 0.04504761]
#  [0.13391113 0.29315186 0.237854   0.13886068]
#  [0.58432282 1.27770434 0.73033003 0.14027154]]
#
#
# compare image "./model/obj1__0.png" to "./model/obj94__0.png":
# [[ 0.13088992  0.12359277  0.25162163  0.05669963]
#  [ 0.36340332  0.4664917   0.49627686  0.21728931]
#  [ 5.01862666 11.07256539  0.82738875  0.70006068]]
#
#
# PART 3A :
# PART 3B :
# PART 3C :
# number of correct matches: 79 (0.887640)
#
# PART 4 :
# num_bins: 10
# num_bins: 20
# num_bins: 30
# num_bins: 40
# num_bins: 50
